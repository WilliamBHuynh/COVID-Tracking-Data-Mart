# %% [markdown]
# ## PHU dimension

# %%
import pandas as pd
import numpy as np

from datetime import datetime, timedelta

# %%
cases = pd.read_csv("conposcovidloc.csv")

# %%
cases.head()
# Out:
#    Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 0       1            2020-06-16         2020-06-17         2020-06-17
# 1       2            2020-05-14         2020-05-16         2020-05-16
# 2       3            2020-04-30         2020-05-01         2020-05-01
# 3       4            2020-04-14         2020-04-17         2020-04-17
# 4       5            2020-07-01         2020-07-07         2020-07-07
#
#   Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  Outcome1  \
# 0    2020-06-16       40s        FEMALE                   OB  Resolved
# 1    2020-05-14       30s        FEMALE                   OB  Resolved
# 2    2020-05-01       50s        FEMALE                   OB  Resolved
# 3    2020-04-15       40s        FEMALE                   OB  Resolved
# 4    2020-07-06       40s          MALE                   OB  Resolved
#
#   Outbreak_Related  Reporting_PHU_ID       Reporting_PHU  \
# 0              Yes              2253  Peel Public Health
# 1              Yes              2253  Peel Public Health
# 2              Yes              2253  Peel Public Health
# 3              Yes              2253  Peel Public Health
# 4              NaN              2253  Peel Public Health
#
#     Reporting_PHU_Address Reporting_PHU_City Reporting_PHU_Postal_Code  \
# 0  7120 Hurontario Street        Mississauga                   L5W 1N4
# 1  7120 Hurontario Street        Mississauga                   L5W 1N4
# 2  7120 Hurontario Street        Mississauga                   L5W 1N4
# 3  7120 Hurontario Street        Mississauga                   L5W 1N4
# 4  7120 Hurontario Street        Mississauga                   L5W 1N4
#
#        Reporting_PHU_Website  Reporting_PHU_Latitude  Reporting_PHU_Longitude
# 0  www.peelregion.ca/health/               43.647471               -79.708893
# 1  www.peelregion.ca/health/               43.647471               -79.708893
# 2  www.peelregion.ca/health/               43.647471               -79.708893
# 3  www.peelregion.ca/health/               43.647471               -79.708893
# 4  www.peelregion.ca/health/               43.647471               -79.708893

# %%
PHU_dimension = pd.DataFrame(columns=['PHU_Surrogate_Key','PHU_Key', 'PHU_Name','Address', 'City', 'Province',
                                     'Postal_Code', 'URL', 'Latitude', 'Longitude'])

# %%
PHU_dimension

for idx, row in cases.iterrows():
    
    if row["Reporting_PHU"] == "Toronto Public Health":
        PHU_row = [idx + 100]
        PHU_row.append(row["Row_ID"])
        PHU_row.append(row['Reporting_PHU'])
        PHU_row.append(row['Reporting_PHU_Address'])
        PHU_row.append(row['Reporting_PHU_City'])
        PHU_row.append("Ontario")  
        PHU_row.append(row['Reporting_PHU_Postal_Code'])
        PHU_row.append(row['Reporting_PHU_Website'])
        PHU_row.append(row['Reporting_PHU_Latitude'])
        PHU_row.append(row['Reporting_PHU_Longitude'])        
        PHU_dimension.loc[len(PHU_dimension)] = PHU_row
        break
for idx, row in cases.iterrows():
    
    if row["Reporting_PHU"] == "Ottawa Public Health":
        PHU_row = [idx + 100]
        PHU_row.append(row["Row_ID"])
        PHU_row.append(row['Reporting_PHU'])
        PHU_row.append(row['Reporting_PHU_Address'])
        PHU_row.append(row['Reporting_PHU_City'])
        PHU_row.append("Ontario")  
        PHU_row.append(row['Reporting_PHU_Postal_Code'])
        PHU_row.append(row['Reporting_PHU_Website'])
        PHU_row.append(row['Reporting_PHU_Latitude'])
        PHU_row.append(row['Reporting_PHU_Longitude'])        
        PHU_dimension.loc[len(PHU_dimension)] = PHU_row
        break

# %%
PHU_dimension
# Out:
#   PHU_Surrogate_Key PHU_Key               PHU_Name  \
# 0               194      95  Toronto Public Health
# 1              3244    3145   Ottawa Public Health
#
#                           Address     City Province Postal_Code  \
# 0  277 Victoria Street, 5th Floor  Toronto  Ontario     M5B 1W2
# 1         100 Constellation Drive   Ottawa  Ontario     K2G 6J8
#
#                                                  URL   Latitude  Longitude
# 0  www.toronto.ca/community-people/health-wellnes...  43.656591 -79.379358
# 1                          www.ottawapublichealth.ca  45.345665 -75.763912

# %%
# export PHU dimension to csv file

PHU_dimension.to_csv("PHU_dimension.csv",index=False)

# %% [markdown]
# # Date dimensions

# %%
dates = pd.read_csv("Extended_Date_Table.csv")

# %%
dates.head()
# Out:
#    Date_Key Date_Full_Format  Day  Month  Year Day_of_Week_Name  \
# 0         1       2020-03-23   23      3  2020           Monday
# 1         2       2020-03-24   24      3  2020          Tuesday
# 2         3       2020-03-25   25      3  2020        Wednesday
# 3         4       2020-03-26   26      3  2020         Thursday
# 4         5       2020-03-27   27      3  2020           Friday
#
#    Day_of_Week_Num  Week_in_Year Weekend_YN Holiday_YN  Season
# 0                2            13          N          N  Spring
# 1                3            13          N          N  Spring
# 2                4            13          N          N  Spring
# 3                5            13          N          N  Spring
# 4                6            13          N          N  Spring

# %%
Onset_dimension = pd.DataFrame(columns=['Onset_Date_Surrogate_Key','Onset_Date_Key', 'Date_Full_Format', 'Day','Month', 
                                        'Year', 'Day_of_Week_Name','Day_of_Week_Num', 'Week_in_Year', 'Weekend', 'Holiday', 
                                        'Season'])

Reported_dimension = pd.DataFrame(columns=['Reported_Date_Surrogate_Key','Reported_Date_Key', 'Date_Full_Format', 'Day','Month',
                                           'Year', 'Day_of_Week_Name','Day_of_Week_Num', 'Week_in_Year', 'Weekend', 'Holiday',
                                           'Season'])

Test_dimension = pd.DataFrame(columns=['Test_Date_Surrogate_Key','Test_Date_Key', 'Date_Full_Format', 'Day','Month', 
                                       'Year', 'Day_of_Week_Name','Day_of_Week_Num', 'Week_in_Year', 'Weekend', 'Holiday', 
                                       'Season'])

Specimen_dimension = pd.DataFrame(columns=['Specimen_Date_Surrogate_Key','Specimen_Date_Key', 'Date_Full_Format', 'Day','Month',
                                           'Year', 'Day_of_Week_Name','Day_of_Week_Num', 'Week_in_Year', 'Weekend', 'Holiday', 
                                           'Season'])

# %%
#Onset_dimension 

for idx, row in dates.iterrows():
    onset_row = [idx + 100]
    onset_row.append(row["Date_Key"])
    onset_row.append(row['Date_Full_Format']) 
    onset_row.append(row['Day'])
    onset_row.append(row['Month'])
    onset_row.append(row['Year'])
    onset_row.append(row['Day_of_Week_Name'])  
    onset_row.append(row['Day_of_Week_Num']) 
    onset_row.append(row["Week_in_Year"])
    onset_row.append(row['Weekend_YN'])
    onset_row.append(row['Holiday_YN'])
    onset_row.append(row['Season'])
    Onset_dimension.loc[len(Onset_dimension)] = onset_row

Onset_dimension
# Out:
#     Onset_Date_Surrogate_Key Onset_Date_Key Date_Full_Format Day Month  Year  \
# 0                        100              1       2020-03-23  23     3  2020
# 1                        101              2       2020-03-24  24     3  2020
# 2                        102              3       2020-03-25  25     3  2020
# 3                        103              4       2020-03-26  26     3  2020
# 4                        104              5       2020-03-27  27     3  2020
# ..                       ...            ...              ...  ..   ...   ...
# 349                      449            350       2021-03-07   7     3  2021
# 350                      450            351       2021-03-08   8     3  2021
# 351                      451            352       2021-03-09   9     3  2021
# 352                      452            353       2021-03-10  10     3  2021
# 353                      453            354       2021-03-11  11     3  2021
#
#     Day_of_Week_Name Day_of_Week_Num Week_in_Year Weekend Holiday  Season
# 0             Monday               2           13       N       N  Spring
# 1            Tuesday               3           13       N       N  Spring
# 2          Wednesday               4           13       N       N  Spring
# 3           Thursday               5           13       N       N  Spring
# 4             Friday               6           13       N       N  Spring
# ..               ...             ...          ...     ...     ...     ...
# 349           Sunday               1           11       Y       N  Winter
# 350           Monday               2           11       N       N  Winter
# 351          Tuesday               3           11       N       N  Winter
# 352        Wednesday               4           11       N       N  Winter
# 353         Thursday               5           11       N       N  Winter
#
# [354 rows x 12 columns]

# %%
#Reported_dimension 

for idx, row in dates.iterrows():
    reported_row = [idx + 500]
    reported_row.append(row["Date_Key"])
    reported_row.append(row['Date_Full_Format']) 
    reported_row.append(row['Day'])
    reported_row.append(row['Month'])
    reported_row.append(row['Year'])
    reported_row.append(row['Day_of_Week_Name'])  
    reported_row.append(row['Day_of_Week_Num']) 
    reported_row.append(row["Week_in_Year"])
    reported_row.append(row['Weekend_YN'])
    reported_row.append(row['Holiday_YN'])
    reported_row.append(row['Season'])
    Reported_dimension.loc[len(Reported_dimension)] = reported_row

Reported_dimension
# Out:
#     Reported_Date_Surrogate_Key Reported_Date_Key Date_Full_Format Day Month  \
# 0                           500                 1       2020-03-23  23     3
# 1                           501                 2       2020-03-24  24     3
# 2                           502                 3       2020-03-25  25     3
# 3                           503                 4       2020-03-26  26     3
# 4                           504                 5       2020-03-27  27     3
# ..                          ...               ...              ...  ..   ...
# 349                         849               350       2021-03-07   7     3
# 350                         850               351       2021-03-08   8     3
# 351                         851               352       2021-03-09   9     3
# 352                         852               353       2021-03-10  10     3
# 353                         853               354       2021-03-11  11     3
#
#      Year Day_of_Week_Name Day_of_Week_Num Week_in_Year Weekend Holiday  \
# 0    2020           Monday               2           13       N       N
# 1    2020          Tuesday               3           13       N       N
# 2    2020        Wednesday               4           13       N       N
# 3    2020         Thursday               5           13       N       N
# 4    2020           Friday               6           13       N       N
# ..    ...              ...             ...          ...     ...     ...
# 349  2021           Sunday               1           11       Y       N
# 350  2021           Monday               2           11       N       N
# 351  2021          Tuesday               3           11       N       N
# 352  2021        Wednesday               4           11       N       N
# 353  2021         Thursday               5           11       N       N
#
#      Season
# 0    Spring
# 1    Spring
# 2    Spring
# 3    Spring
# 4    Spring
# ..      ...
# 349  Winter
# 350  Winter
# 351  Winter
# 352  Winter
# 353  Winter
#
# [354 rows x 12 columns]

# %%
#Test_dimension 

for idx, row in dates.iterrows():
    test_row = [idx + 1000]
    test_row.append(row["Date_Key"])
    test_row.append(row['Date_Full_Format']) 
    test_row.append(row['Day'])
    test_row.append(row['Month'])
    test_row.append(row['Year'])
    test_row.append(row['Day_of_Week_Name'])  
    test_row.append(row['Day_of_Week_Num']) 
    test_row.append(row["Week_in_Year"])
    test_row.append(row['Weekend_YN'])
    test_row.append(row['Holiday_YN'])
    test_row.append(row['Season'])
    Test_dimension.loc[len(Test_dimension)] = test_row

Test_dimension
# Out:
#     Test_Date_Surrogate_Key Test_Date_Key Date_Full_Format Day Month  Year  \
# 0                      1000             1       2020-03-23  23     3  2020
# 1                      1001             2       2020-03-24  24     3  2020
# 2                      1002             3       2020-03-25  25     3  2020
# 3                      1003             4       2020-03-26  26     3  2020
# 4                      1004             5       2020-03-27  27     3  2020
# ..                      ...           ...              ...  ..   ...   ...
# 349                    1349           350       2021-03-07   7     3  2021
# 350                    1350           351       2021-03-08   8     3  2021
# 351                    1351           352       2021-03-09   9     3  2021
# 352                    1352           353       2021-03-10  10     3  2021
# 353                    1353           354       2021-03-11  11     3  2021
#
#     Day_of_Week_Name Day_of_Week_Num Week_in_Year Weekend Holiday  Season
# 0             Monday               2           13       N       N  Spring
# 1            Tuesday               3           13       N       N  Spring
# 2          Wednesday               4           13       N       N  Spring
# 3           Thursday               5           13       N       N  Spring
# 4             Friday               6           13       N       N  Spring
# ..               ...             ...          ...     ...     ...     ...
# 349           Sunday               1           11       Y       N  Winter
# 350           Monday               2           11       N       N  Winter
# 351          Tuesday               3           11       N       N  Winter
# 352        Wednesday               4           11       N       N  Winter
# 353         Thursday               5           11       N       N  Winter
#
# [354 rows x 12 columns]

# %%
#Specimen_dimension 

for idx, row in dates.iterrows():
    specimen_row = [idx + 1500]
    specimen_row.append(row["Date_Key"])
    specimen_row.append(row['Date_Full_Format']) 
    specimen_row.append(row['Day'])
    specimen_row.append(row['Month'])
    specimen_row.append(row['Year'])
    specimen_row.append(row['Day_of_Week_Name'])  
    specimen_row.append(row['Day_of_Week_Num']) 
    specimen_row.append(row["Week_in_Year"])
    specimen_row.append(row['Weekend_YN'])
    specimen_row.append(row['Holiday_YN'])
    specimen_row.append(row['Season'])
    Specimen_dimension.loc[len(Specimen_dimension)] = specimen_row

Specimen_dimension
# Out:
#     Specimen_Date_Surrogate_Key Specimen_Date_Key Date_Full_Format Day Month  \
# 0                          1500                 1       2020-03-23  23     3
# 1                          1501                 2       2020-03-24  24     3
# 2                          1502                 3       2020-03-25  25     3
# 3                          1503                 4       2020-03-26  26     3
# 4                          1504                 5       2020-03-27  27     3
# ..                          ...               ...              ...  ..   ...
# 349                        1849               350       2021-03-07   7     3
# 350                        1850               351       2021-03-08   8     3
# 351                        1851               352       2021-03-09   9     3
# 352                        1852               353       2021-03-10  10     3
# 353                        1853               354       2021-03-11  11     3
#
#      Year Day_of_Week_Name Day_of_Week_Num Week_in_Year Weekend Holiday  \
# 0    2020           Monday               2           13       N       N
# 1    2020          Tuesday               3           13       N       N
# 2    2020        Wednesday               4           13       N       N
# 3    2020         Thursday               5           13       N       N
# 4    2020           Friday               6           13       N       N
# ..    ...              ...             ...          ...     ...     ...
# 349  2021           Sunday               1           11       Y       N
# 350  2021           Monday               2           11       N       N
# 351  2021          Tuesday               3           11       N       N
# 352  2021        Wednesday               4           11       N       N
# 353  2021         Thursday               5           11       N       N
#
#      Season
# 0    Spring
# 1    Spring
# 2    Spring
# 3    Spring
# 4    Spring
# ..      ...
# 349  Winter
# 350  Winter
# 351  Winter
# 352  Winter
# 353  Winter
#
# [354 rows x 12 columns]

# %%
# export date dimensions to csv files

Onset_dimension.to_csv("Onset_Date_dimension.csv",index=False)
Reported_dimension.to_csv("Reported_Date_dimension.csv",index=False)
Test_dimension.to_csv("Test_Date_dimension.csv",index=False)
Specimen_dimension.to_csv("Specimen_Date_dimension.csv",index=False)

# %% [markdown]
# # Patient dimension

# %%
cases.head()
# Out:
#    Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 0       1            2020-06-16         2020-06-17         2020-06-17
# 1       2            2020-05-14         2020-05-16         2020-05-16
# 2       3            2020-04-30         2020-05-01         2020-05-01
# 3       4            2020-04-14         2020-04-17         2020-04-17
# 4       5            2020-07-01         2020-07-07         2020-07-07
#
#   Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  Outcome1  \
# 0    2020-06-16       40s        FEMALE                   OB  Resolved
# 1    2020-05-14       30s        FEMALE                   OB  Resolved
# 2    2020-05-01       50s        FEMALE                   OB  Resolved
# 3    2020-04-15       40s        FEMALE                   OB  Resolved
# 4    2020-07-06       40s          MALE                   OB  Resolved
#
#   Outbreak_Related  Reporting_PHU_ID       Reporting_PHU  \
# 0              Yes              2253  Peel Public Health
# 1              Yes              2253  Peel Public Health
# 2              Yes              2253  Peel Public Health
# 3              Yes              2253  Peel Public Health
# 4              NaN              2253  Peel Public Health
#
#     Reporting_PHU_Address Reporting_PHU_City Reporting_PHU_Postal_Code  \
# 0  7120 Hurontario Street        Mississauga                   L5W 1N4
# 1  7120 Hurontario Street        Mississauga                   L5W 1N4
# 2  7120 Hurontario Street        Mississauga                   L5W 1N4
# 3  7120 Hurontario Street        Mississauga                   L5W 1N4
# 4  7120 Hurontario Street        Mississauga                   L5W 1N4
#
#        Reporting_PHU_Website  Reporting_PHU_Latitude  Reporting_PHU_Longitude
# 0  www.peelregion.ca/health/               43.647471               -79.708893
# 1  www.peelregion.ca/health/               43.647471               -79.708893
# 2  www.peelregion.ca/health/               43.647471               -79.708893
# 3  www.peelregion.ca/health/               43.647471               -79.708893
# 4  www.peelregion.ca/health/               43.647471               -79.708893

# %%
Patient_dimension = pd.DataFrame(columns=['Patient_Surrogate_Key','Patient_Key', 'Age', 'Gender', 'Acquisition_Group', 
                                          'Outbreak_Related'])

# %%
age_unique = cases['Age_Group'].unique()
gender_unique = cases['Client_Gender'].unique()
acq_unique = cases['Case_AcquisitionInfo'].unique()
or_unique = cases['Outbreak_Related'].unique()

print(age_unique, "\n", gender_unique, "\n", acq_unique, "\n", or_unique)
# Out:
# ['40s' '30s' '50s' '60s' '80s' '20s' '70s' '90+' '<20' 'UNKNOWN']
#  ['FEMALE' 'MALE' 'UNSPECIFIED' 'GENDER DIVERSE']
#  ['OB' 'NO KNOWN EPI LINK' 'CC' 'TRAVEL' 'MISSING INFORMATION'
#  'UNSPECIFIED EPI LINK']
#  ['Yes' nan]

# %%
index = pd.MultiIndex.from_product([age_unique, gender_unique, acq_unique, or_unique], 
                                   names = ["Age", "Gender", "Acquisition_Group", "Outbreak_Related"])

joined = pd.DataFrame(index = index).reset_index()
joined
# Out:
#          Age          Gender     Acquisition_Group Outbreak_Related
# 0        40s          FEMALE                    OB              Yes
# 1        40s          FEMALE                    OB              NaN
# 2        40s          FEMALE     NO KNOWN EPI LINK              Yes
# 3        40s          FEMALE     NO KNOWN EPI LINK              NaN
# 4        40s          FEMALE                    CC              Yes
# ..       ...             ...                   ...              ...
# 475  UNKNOWN  GENDER DIVERSE                TRAVEL              NaN
# 476  UNKNOWN  GENDER DIVERSE   MISSING INFORMATION              Yes
# 477  UNKNOWN  GENDER DIVERSE   MISSING INFORMATION              NaN
# 478  UNKNOWN  GENDER DIVERSE  UNSPECIFIED EPI LINK              Yes
# 479  UNKNOWN  GENDER DIVERSE  UNSPECIFIED EPI LINK              NaN
#
# [480 rows x 4 columns]

# %%
for idx, row in joined.iterrows():
    
    patient_row = [idx + 1000]
    patient_row.append(idx)
    patient_row.append(row['Age'])
    patient_row.append(row['Gender'])
    patient_row.append(row['Acquisition_Group'])
    patient_row.append(row['Outbreak_Related'])  
    Patient_dimension.loc[len(Patient_dimension)] = patient_row

Patient_dimension
# Out:
#     Patient_Surrogate_Key Patient_Key      Age          Gender  \
# 0                    1000           0      40s          FEMALE
# 1                    1001           1      40s          FEMALE
# 2                    1002           2      40s          FEMALE
# 3                    1003           3      40s          FEMALE
# 4                    1004           4      40s          FEMALE
# ..                    ...         ...      ...             ...
# 475                  1475         475  UNKNOWN  GENDER DIVERSE
# 476                  1476         476  UNKNOWN  GENDER DIVERSE
# 477                  1477         477  UNKNOWN  GENDER DIVERSE
# 478                  1478         478  UNKNOWN  GENDER DIVERSE
# 479                  1479         479  UNKNOWN  GENDER DIVERSE
#
#         Acquisition_Group Outbreak_Related
# 0                      OB              Yes
# 1                      OB              NaN
# 2       NO KNOWN EPI LINK              Yes
# 3       NO KNOWN EPI LINK              NaN
# 4                      CC              Yes
# ..                    ...              ...
# 475                TRAVEL              NaN
# 476   MISSING INFORMATION              Yes
# 477   MISSING INFORMATION              NaN
# 478  UNSPECIFIED EPI LINK              Yes
# 479  UNSPECIFIED EPI LINK              NaN
#
# [480 rows x 6 columns]

# %%
# export patient dimension to csv file

Patient_dimension.to_csv("Patient_dimension.csv",index=False)
