# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None

from datetime import datetime, timedelta

# %% [markdown]
# ### Loading Data
# Loading and displaying the two ottawa datasets
# One is labelled as missing as we will use this data set to supplement the missing values from the IntlA station
# We use the closest weather station to each IntlA station and take the date range from 2020-10-27 to 2021-02-27

# %%
climate_ottawa = pd.read_csv(r"Ottawa_IntlA_Total.csv")
climate_ottawa_missing = pd.read_csv(r"Ottawa_CDA_Total.csv")

climate_ottawa.tail()
# Out:
#      Longitude (x)  Latitude (y)   Station Name  Climate ID   Date/Time  Year  \
# 424         -75.67         45.32  OTTAWA INTL A     6106001  2021-02-28  2021
# 425         -75.67         45.32  OTTAWA INTL A     6106001  2021-03-01  2021
# 426         -75.67         45.32  OTTAWA INTL A     6106001  2021-03-02  2021
# 427         -75.67         45.32  OTTAWA INTL A     6106001  2021-03-03  2021
# 428         -75.67         45.32  OTTAWA INTL A     6106001  2021-03-04  2021
#
#      Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 424      2   28           NaN            4.4  ...             0.0
# 425      3    1           NaN            3.8  ...             0.0
# 426      3    2           NaN           -7.3  ...             6.4
# 427      3    3           NaN           -0.4  ...             0.0
# 428      3    4           NaN           -4.9  ...             0.0
#
#      Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 424                T               1.0                NaN              58.0
# 425                T               1.5                NaN              52.0
# 426              NaN               4.0                NaN              48.0
# 427                T               0.0                  T              55.0
# 428              NaN               0.0                NaN              55.0
#
#      Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 424                NaN                      15.0                   NaN
# 425                NaN                      31.0                   NaN
# 426                NaN                      30.0                   NaN
# 427                NaN                      32.0                   NaN
# 428                NaN                      33.0                   NaN
#
#     Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 424                   41.0                   NaN
# 425                   68.0                   NaN
# 426                   58.0                   NaN
# 427                   33.0                   NaN
# 428                   48.0                   NaN
#
# [5 rows x 31 columns]

# %%
climate_ottawa_missing.tail()
# Out:
#      Longitude (x)  Latitude (y)    Station Name  Climate ID   Date/Time  \
# 424         -75.72         45.38  OTTAWA CDA RCS     6105978  2021-02-28
# 425         -75.72         45.38  OTTAWA CDA RCS     6105978  2021-03-01
# 426         -75.72         45.38  OTTAWA CDA RCS     6105978  2021-03-02
# 427         -75.72         45.38  OTTAWA CDA RCS     6105978  2021-03-03
# 428         -75.72         45.38  OTTAWA CDA RCS     6105978  2021-03-04
#
#      Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 424  2021      2   28           NaN            4.8  ...             NaN
# 425  2021      3    1           NaN            4.5  ...             NaN
# 426  2021      3    2           NaN           -7.0  ...             NaN
# 427  2021      3    3           NaN            0.0  ...             NaN
# 428  2021      3    4           NaN           -3.8  ...             NaN
#
#      Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 424              NaN               1.1                NaN              56.0
# 425              NaN               2.4                NaN              49.0
# 426              NaN               4.4                NaN              45.0
# 427              NaN               0.2                NaN              49.0
# 428              NaN               0.0                NaN              50.0
#
#      Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 424                NaN                      11.0                   NaN
# 425                NaN                      31.0                   NaN
# 426                NaN                      28.0                   NaN
# 427                NaN                       NaN                   NaN
# 428                NaN                      32.0                   NaN
#
#     Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 424                   32.0                   NaN
# 425                   63.0                   NaN
# 426                   48.0                   NaN
# 427                    NaN                   NaN
# 428                   45.0                   NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Processing
#
# Keeping the columns we want in our data mart and add surrogate keys
# The snow and rain columns were removed. I kept total precipitation instead. $ values from the Ottawa intlA were missing and the altenrative CDA station didn;t have snow and rain data. Instead to avoid null values and removing any dates for the weather I have kept total precipitation.

# %%
ottawa_climate = climate_ottawa[['Station Name','Date/Time','Mean Temp (°C)',  'Min Temp (°C)','Max Temp (°C)', 
                                 'Total Precip (mm)']]

ottawa_climate_missing = climate_ottawa_missing[['Station Name','Date/Time','Mean Temp (°C)',  'Min Temp (°C)','Max Temp (°C)', 
                                 'Total Precip (mm)']]

# %% [markdown]
# The indexes of missing temperature or precipitation values and their corresponding date

# %%
series = ottawa_climate.isnull().any(axis=1)
for index, value in series.iteritems():
    if value == True:
        print("index of: ", index, " Value: ", value)
# Out:
# index of:  107  Value:  True
# index of:  135  Value:  True
# index of:  259  Value:  True
# index of:  362  Value:  True
# index of:  390  Value:  True
# index of:  404  Value:  True
# index of:  410  Value:  True

# %%
index = [107, 135, 259, 362, 404, 410]
for i in index:
    print(ottawa_climate["Date/Time"].loc[[i]])
# Out:
# 107    2020-04-17
# Name: Date/Time, dtype: object
# 135    2020-05-15
# Name: Date/Time, dtype: object
# 259    2020-09-16
# Name: Date/Time, dtype: object
# 362    2020-12-28
# Name: Date/Time, dtype: object
# 404    2021-02-08
# Name: Date/Time, dtype: object
# 410    2021-02-14
# Name: Date/Time, dtype: object

# %%
for i in index:
    ottawa_climate.loc[[i]] = ottawa_climate_missing.loc[[i]]
    print(ottawa_climate.loc[[i]])
# Out:
#        Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 107  OTTAWA CDA RCS  2020-04-17             2.4           -1.2            6.1
#
#      Total Precip (mm)
# 107                0.0
#        Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 135  OTTAWA CDA RCS  2020-05-15            11.1            9.7           12.5
#
#      Total Precip (mm)
# 135               18.3
#        Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 259  OTTAWA CDA RCS  2020-09-16            15.4            8.6           22.2
#
#      Total Precip (mm)
# 259                0.0
#        Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 362  OTTAWA CDA RCS  2020-12-28            -1.2           -6.8            4.3
#
#      Total Precip (mm)
# 362                1.9
#        Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 404  OTTAWA CDA RCS  2021-02-08           -13.5          -20.3           -6.8
#
#      Total Precip (mm)
# 404                0.2
#        Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 410  OTTAWA CDA RCS  2021-02-14           -10.4          -14.3           -6.6
#
#      Total Precip (mm)
# 410                1.1

# %% [markdown]
# ### Toronto Weather
#
# We see that Toronto isn't missing any values from the columns we have kept

# %%
climate_toronto = pd.read_csv(r"Toronto_IntlA_Total.csv")
climate_toronto_missing = pd.read_csv(r"Toronto_City_Total.csv")
toronto_climate = climate_toronto[['Station Name','Date/Time','Mean Temp (°C)',  'Min Temp (°C)','Max Temp (°C)', 
                                 'Total Precip (mm)']]

toronto_climate_missing = climate_toronto_missing[['Station Name','Date/Time','Mean Temp (°C)',  'Min Temp (°C)','Max Temp (°C)', 
                                 'Total Precip (mm)']]
series2 = toronto_climate.isnull().any(axis=1)
for index, value in series2.iteritems():
    if value == True:
        print("index of: ", index, " Value: ", value)
# Out:
# index of:  384  Value:  True
# index of:  413  Value:  True
# index of:  414  Value:  True

# %% [markdown]
# Process the same way as the ottawa data now

# %%
index2 = [384, 413, 414]
for i in index2:
    print(toronto_climate["Date/Time"].loc[[i]])
# Out:
# 384    2021-01-19
# Name: Date/Time, dtype: object
# 413    2021-02-17
# Name: Date/Time, dtype: object
# 414    2021-02-18
# Name: Date/Time, dtype: object

# %%
for i in index2:
    toronto_climate.loc[[i]] = toronto_climate_missing.loc[[i]]
    print(toronto_climate.loc[[i]])
# Out:
#      Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 384  TORONTO CITY  2021-01-19             0.0           -2.2            2.2
#
#      Total Precip (mm)
# 384                0.0
#      Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 413  TORONTO CITY  2021-02-17            -7.6          -12.7           -2.5
#
#      Total Precip (mm)
# 413                0.0
#      Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 414  TORONTO CITY  2021-02-18            -4.4           -6.2           -2.6
#
#      Total Precip (mm)
# 414                3.7

# %% [markdown]
# Join them into a single data frame and write to csv

# %%
ottawa_climate = ottawa_climate[300:423]
toronto_climate = toronto_climate[300:423]
weather_dimension = ottawa_climate.append(toronto_climate, ignore_index=True, sort=False)
weather_dimension.head()
#toronto_climate.insert(0, "surrogate_key",  np.arange(len(toronto_climate)))
#toronto_climate["Date/Time"] = pd.to_datetime(toronto_climate["Date/Time"] ).dt.strftime('%Y-%m-%d')
# Out:
#     Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 0  OTTAWA INTL A  2020-10-27             0.2           -2.3            2.7
# 1  OTTAWA INTL A  2020-10-28             4.2           -1.1            9.4
# 2  OTTAWA INTL A  2020-10-29             2.4           -1.3            6.0
# 3  OTTAWA INTL A  2020-10-30            -0.5           -4.9            3.9
# 4  OTTAWA INTL A  2020-10-31            -1.0           -8.4            6.5
#
#    Total Precip (mm)
# 0                0.0
# 1                0.4
# 2                0.0
# 3                0.0
# 4                0.0

# %%
weather_dimension.tail()
# Out:
#        Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  Max Temp (°C)  \
# 241  TORONTO INTL A  2021-02-22             0.6           -1.7            2.8
# 242  TORONTO INTL A  2021-02-23             1.8           -0.7            4.3
# 243  TORONTO INTL A  2021-02-24             3.9           -0.6            8.4
# 244  TORONTO INTL A  2021-02-25            -1.4           -3.7            0.9
# 245  TORONTO INTL A  2021-02-26            -1.6           -6.9            3.8
#
#      Total Precip (mm)
# 241                4.8
# 242                0.2
# 243                0.0
# 244                0.0
# 245                0.0

# %%
weather_dimension.insert(0, "surrogate_key",  np.arange(len(weather_dimension)))
weather_dimension["Date/Time"] = pd.to_datetime(weather_dimension["Date/Time"] ).dt.strftime('%Y-%m-%d')
weather_dimension.head()
# Out:
#    surrogate_key   Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  \
# 0              0  OTTAWA INTL A  2020-10-27             0.2           -2.3
# 1              1  OTTAWA INTL A  2020-10-28             4.2           -1.1
# 2              2  OTTAWA INTL A  2020-10-29             2.4           -1.3
# 3              3  OTTAWA INTL A  2020-10-30            -0.5           -4.9
# 4              4  OTTAWA INTL A  2020-10-31            -1.0           -8.4
#
#    Max Temp (°C)  Total Precip (mm)
# 0            2.7                0.0
# 1            9.4                0.4
# 2            6.0                0.0
# 3            3.9                0.0
# 4            6.5                0.0

# %%
weather_dimension.tail()
# Out:
#      surrogate_key    Station Name   Date/Time  Mean Temp (°C)  Min Temp (°C)  \
# 241            241  TORONTO INTL A  2021-02-22             0.6           -1.7
# 242            242  TORONTO INTL A  2021-02-23             1.8           -0.7
# 243            243  TORONTO INTL A  2021-02-24             3.9           -0.6
# 244            244  TORONTO INTL A  2021-02-25            -1.4           -3.7
# 245            245  TORONTO INTL A  2021-02-26            -1.6           -6.9
#
#      Max Temp (°C)  Total Precip (mm)
# 241            2.8                4.8
# 242            4.3                0.2
# 243            8.4                0.0
# 244            0.9                0.0
# 245            3.8                0.0

# %%
weather_dimension.to_csv("weather_dimension.csv",index=False)
